# %%
# !pip install feature-engine
# Out:
# Collecting feature-engine
#   Downloading feature_engine-1.1.2-py2.py3-none-any.whl (180 kB)
# Requirement already satisfied: pandas>=1.0.3 in c:\users\admin\anaconda3\lib\site-packages (from feature-engine) (1.1.3)
# Requirement already satisfied: scikit-learn>=0.22.2 in c:\users\admin\anaconda3\lib\site-packages (from feature-engine) (0.23.2)
# Requirement already satisfied: numpy>=1.18.2 in c:\users\admin\anaconda3\lib\site-packages (from feature-engine) (1.19.2)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\admin\anaconda3\lib\site-packages (from feature-engine) (1.5.2)
# Requirement already satisfied: statsmodels>=0.11.1 in c:\users\admin\anaconda3\lib\site-packages (from feature-engine) (0.12.0)
# Requirement already satisfied: pytz>=2017.2 in c:\users\admin\anaconda3\lib\site-packages (from pandas>=1.0.3->feature-engine) (2020.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\admin\anaconda3\lib\site-packages (from pandas>=1.0.3->feature-engine) (2.8.1)
# Requirement already satisfied: joblib>=0.11 in c:\users\admin\anaconda3\lib\site-packages (from scikit-learn>=0.22.2->feature-engine) (0.17.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\admin\anaconda3\lib\site-packages (from scikit-learn>=0.22.2->feature-engine) (2.1.0)
# Requirement already satisfied: patsy>=0.5 in c:\users\admin\anaconda3\lib\site-packages (from statsmodels>=0.11.1->feature-engine) (0.5.1)
# Requirement already satisfied: six>=1.5 in c:\users\admin\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=1.0.3->feature-engine) (1.15.0)
# Installing collected packages: feature-engine
# Successfully installed feature-engine-1.1.2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv('data.csv')

# %%
len(data[data['y']==0])#.head()
#len(data)
# Out:
# 1242

# %%
data.head()
# Out:
#            x1          x2  y
# 0 -119.366669  115.000000  1
# 1 -101.108044   97.777159  1
# 2 -130.278658  106.767654  1
# 3 -114.703415  101.195477  1
# 4 -119.366669  115.000000  1

# %%
print("max values for x1 {} and x2 {}".format(max(data['x1']),max(data['x2'])))
print("min values for x1 {} and x2 {}".format(min(data['x1']),min(data['x2'])))
# Out:
# max values for x1 134.5086874 and x2 99999999.0
# min values for x1 -134.3691605 and x2 -134.8761321

# %%
data[data['x2']>135].sort_values(by=['x2'])
# Out:
#               x1          x2  y
# 1541   66.633331  99009998.0  0
# 2226  109.624009  99999999.0  0

# %%
# print("total number of records given in the data set is {}".format(len(data)))
print("percentage of records with label 0 in the data set is {}".format(len(data[data['y']==0])/len(data)*100))
print("percentage of records with label 1 in the data set is {}".format(len(data[data['y']==1])/len(data)*100))
# Out:
# percentage of records with label 0 in the data set is 55.77009429726088
# percentage of records with label 1 in the data set is 44.22990570273911

# %% [markdown]
# ### almost 56% of the records belong to label 0 and rest to label 1

# %%
data.head()
len(data['x2'].unique())
# Out:
# 1885

# %%
data['x2'].nlargest(3)
# Out:
# 2226    1.000000e+08
# 1541    9.901000e+07
# 1948    1.349297e+02
# Name: x2, dtype: float64

# %%
replcae_extreme = 1.349297e+02

# %%
data['x2'] = data['x2'].replace([99009998.0,99999999.0],replcae_extreme)

# %%
data['x2']
# Out:
# 0       115.000000
# 1        97.777159
# 2       106.767654
# 3       101.195477
# 4       115.000000
#            ...
# 2222     89.643117
# 2223     91.000000
# 2224    103.839270
# 2225     78.605371
# 2226    134.929700
# Name: x2, Length: 2227, dtype: float64

# %%
data[data['x2']>135].sort_values(by=['x2'])
# Out:
# Empty DataFrame
# Columns: [x1, x2, y]
# Index: []

# %%
def plot_hist(data, feature, title):
    fig = data[feature].hist(bins=50)
    fig.set_title(title)

# %%
plot_hist(data, 'x1', 'x1plot')

# %%
fig = data['x2'].hist(bins=50, range=(-200, 200))

# %%
features_with_na=[features for features in data.columns if data[features].isnull().sum()>1]

for feature in features_with_na:
    print(feature, np.round(data[feature].isnull().mean(), 4),  ' % missing values')
# Out:
# x1 0.0022  % missing values
# x2 0.0013  % missing values

# %%
data['x2'].isnull().sum()
# Out:
# 3

# %%
data[data['x2'].isnull()]
# Out:
#              x1  x2  y
# 44   -99.627522 NaN  1
# 1092  55.162258 NaN  0
# 1430 -74.126054 NaN  0

# %%
def diagnostic_plots(df, variable):
   
    plt.figure(figsize=(16, 4))

    # histogram
    plt.subplot(1, 3, 1)
    sns.histplot(df[variable], bins=30)
    plt.title('Histogram')

    # Q-Q plot
    plt.subplot(1, 3, 2)
    stats.probplot(df[variable], dist="norm", plot=plt)
    plt.ylabel('Variable quantiles')

    # boxplot
    plt.subplot(1, 3, 3)
    sns.boxplot(y=df[variable])#, ylim=(0,200))
    plt.ylim(-200, 200)
    plt.title('Boxplot')

    plt.show()

# %%
diagnostic_plots(data, 'x2')

# %%
diagnostic_plots(data, 'x1')

# %%
from feature_engine.imputation import MeanMedianImputer
imputer = MeanMedianImputer(imputation_method='median')
imputer.fit(data)
data = imputer.transform(data)

# %%
cols_to_use = ['x1','x2']

# %%
X_train, X_test, y_train, y_test = train_test_split(data[cols_to_use],
                                                    data['y'],
                                                    test_size=0.3,
                                                    random_state=42)

# %%
print(len(y_test[y_test==1]),len(y_test[y_test==0]))
# Out:
# 306 363

# %%
Xy = data.dropna()
X = data.drop(columns=['y'])
y = data['y']
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in X:
    if plotnumber<=3 :
        ax = plt.subplot(3,1,plotnumber)
        sns.stripplot(y,X[column])
    plotnumber+=1
plt.tight_layout()
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Since the percentage of missing values is too less we can consider dropping those records, but I have gone about used imputation technique.

# %%
# from feature_engine.imputation import MeanMedianImputer
# imputer = MeanMedianImputer(imputation_method='median')
# imputer.fit(X_train)
# Out:
# MeanMedianImputer()

# %%
# X_train = imputer.transform(X_train)

# %%
# imputer.imputer_dict_
type(X_train)
# Out:
# pandas.core.frame.DataFrame

# %%
# imputer1 = MeanMedianImputer(imputation_method='median')
# imputer1.fit(X_test)
# X_test = imputer.transform(X_test)

# %% [markdown]
# # Logistic Regression

# %%
scaler = StandardScaler()

# %%
scaled_X_train = scaler.fit_transform(X_train)
scaled_X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_model = LogisticRegression()

# %%
log_model.fit(scaled_X_train,y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,plot_confusion_matrix

# %%
y_pred = log_model.predict(scaled_X_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.7234678624813154

# %%
plot_confusion_matrix(log_model,scaled_X_test,y_test,normalize='true')

# %% [markdown]
# # Support Vector machines

# %%
from sklearn.svm import SVC

# %%
sns.scatterplot(x='x1',y='x2',hue='y',palette='seismic',data=data)
# Out:
# <AxesSubplot:xlabel='x1', ylabel='x2'>

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV

# %%
svc = SVC(random_state=42, kernel='linear')

# %%
param_grid = {'C':[0.01,0.1,0.5,1,20,100],'gamma':['scale','auto']}
grid = GridSearchCV(svc,param_grid)

# %%
grid.fit(scaled_X_train,y_train)
# Out:
# GridSearchCV(estimator=SVC(kernel='linear', random_state=42),
#              param_grid={'C': [0.01, 0.1, 0.5, 1, 20, 100],
#                          'gamma': ['scale', 'auto']})

# %%
grid.best_params_
# Out:
# {'C': 0.5, 'gamma': 'scale'}

# %%
grid_pred = grid.predict(scaled_X_test)

# %%
confusion_matrix(y_test,grid_pred)
# Out:
# array([[363,   0],
#        [185, 121]], dtype=int64)

# %%
print(classification_report(y_test,grid_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      1.00      0.80       363
#            1       1.00      0.40      0.57       306
#
#     accuracy                           0.72       669
#    macro avg       0.83      0.70      0.68       669
# weighted avg       0.82      0.72      0.69       669

# %%
accuracy_score(y_test,grid_pred)
# Out:
# 0.7234678624813154

# %% [markdown]
# ## RBF kernel

# %%
svf = SVC(random_state=12, kernel='rbf')

# %%
param_grid1 = {'C':[0.01,0.1,0.5,1,20,100,120,135,200],'gamma':['scale','auto']}
grid1 = GridSearchCV(svf,param_grid1)

# %%
grid1.fit(scaled_X_train,y_train)
# Out:
# GridSearchCV(estimator=SVC(random_state=12),
#              param_grid={'C': [0.01, 0.1, 0.5, 1, 20, 100, 120, 135, 200],
#                          'gamma': ['scale', 'auto']})

# %%
grid1.best_params_
# Out:
# {'C': 120, 'gamma': 'scale'}

# %%
grid_pred_f = grid1.predict(scaled_X_test)

# %%
confusion_matrix(y_test,grid_pred_f)
# Out:
# array([[346,  17],
#        [  8, 298]], dtype=int64)

# %%
print(classification_report(y_test,grid_pred_f))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.95      0.97       363
#            1       0.95      0.97      0.96       306
#
#     accuracy                           0.96       669
#    macro avg       0.96      0.96      0.96       669
# weighted avg       0.96      0.96      0.96       669

# %%
accuracy_score(y_test,grid_pred_f)
# Out:
# 0.9626307922272048

# %% [markdown]
# # Decsion tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier()

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import plot_tree

# %%
plt.figure(figsize=(12,8),dpi=150)
plot_tree(model,filled=True,feature_names=data.columns);

# %%
def report_model(model):
    model_preds = model.predict(X_test)
    print(classification_report(y_test,model_preds))
    print('\n')
    plt.figure(figsize=(12,8),dpi=150)
    plot_tree(model,filled=True,feature_names=X.columns)

# %%
report_model(model)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95       363
#            1       0.93      0.95      0.94       306
#
#     accuracy                           0.95       669
#    macro avg       0.95      0.95      0.95       669
# weighted avg       0.95      0.95      0.95       669

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn_model = KNeighborsClassifier(n_neighbors=1)

# %%
knn_model.fit(scaled_X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
y_pred = knn_model.predict(scaled_X_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9566517189835575

# %% [markdown]
# # Compared to logistic regression and svm we can see thast knn and decision tree is giving better results it could be becauise of the fact that the data is not nornmally distributed and can not be linearly separable therefpre knn and decision tree performs better
